# %%
from bs4 import BeautifulSoup
# importando request
import requests

# se define variable con url sólo por orden
url = 'https://www.leggenda.cl/'

# obtención de la página que se va a analizar
page = requests.get(url)

print(f"Codigo: {page.status_code}")

# el contenido de la pagina se encuentra en page.content, y con esto se lee con BeautifulSoap
from bs4 import BeautifulSoup
page = BeautifulSoup(page.content, 'html.parser')
print(page.prettify())

##
# Out:
# Codigo: 200
# <!DOCTYPE html>
# <html class="no-js" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, height=device-height, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <meta content="" name="theme-color"/>
#   <title>
#    LEGGENDA - Joyas y Accesorios – Leggenda - Joyas y Accesorios
#   </title>
#   <meta content="Hermosa linea de Cadenas, Pulseras, Brazaletes, Anillos y Aros. Forjados en acero inoxidable 316L. Material Perfecto para utilizarlas día a día bajo cualquier circunstancia." name="description"/>
#   <link href="https://www.leggenda.cl/" rel="canonical"/>
#   <link href="//cdn.shopify.com/s/files/1/0489/7128/4644/files/WhatsApp_Image_2020-09-22_at_21.34.26_96x.jpeg?v=1614300497" rel="shortcut icon" type="image/png"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
#Extrayendo los links y categorias del eCommerce
all_a = page.find_all('a',href=True)

for a in all_a:
    print(a['href'])
# Out:
# #main
# /collections/coleccion-2021
# /collections/anteojos-de-sol
# /collections/frontpage
# /collections/bracelets
# /collections/rings
# /collections/aros
# /collections/para-ella
# /collections/linea-de-ropa
# /collections
# /account
# /collections/coleccion-2021
# /collections/anteojos-de-sol
# /collections/frontpage
# /collections/bracelets
# /collections/rings
# /collections/aros
# /collections/para-ella
# /collections/linea-de-ropa
# /collections
# /
# /account
# /search
# /cart
# /collections/anteojos-de-sol
# /collections/coleccion-2021
# /collections/linea-de-ropa
# /products/retro-pilot
# /products/retro-pilot
# /products/polygon-vintage
# /products/polygon-vintage
# /products/square-leopard-retro
# /products/square-leopard-retro
# /products/square-black-retro
# /products/square-black-retro
# /products/tortoise-black
# /products/tortoise-black
# /products/tortoise-leopard
# /products/tortoise-leopard
# /products/jack-black-leopard
# /products/jack-black-leopard
# ...

# %%
all_products = page.find_all(class_='ProductItem')
print(len(all_products))
# Out:
# 27

# %%
all_products = page.find_all(class_='ProductItem')
print(len(all_products))

 # obteniendo el nombre en una lista de elementos [ ] sin .string. Para conseguir el texto debe se debe elimim¿nar la variable all de la busqueda 
 # de elementos

for product in all_products:
    name_products = product.find_all(class_='ProductItem__Title Heading')
    print(name_products)
# Out:
# 27
# [<h2 class="ProductItem__Title Heading">
# <a href="/products/retro-pilot">Retro Pilot</a>
# </h2>]
# [<h2 class="ProductItem__Title Heading">
# <a href="/products/polygon-vintage">Polygon Vintage</a>
# </h2>]
# [<h2 class="ProductItem__Title Heading">
# <a href="/products/square-leopard-retro">Square Leopard Retro</a>
# </h2>]
# [<h2 class="ProductItem__Title Heading">
# <a href="/products/square-black-retro">Square Black Retro</a>
# </h2>]
# [<h2 class="ProductItem__Title Heading">
# <a href="/products/tortoise-black">Tortoise Black</a>
# </h2>]
# [<h2 class="ProductItem__Title Heading">
# <a href="/products/tortoise-leopard">Tortoise Leopard</a>
# </h2>]
# [<h2 class="ProductItem__Title Heading">
# <a href="/products/jack-black-leopard">Jack Black Leopard</a>
# </h2>]
# [<h2 class="ProductItem__Title Heading">
# <a href="/products/jack-black">Jack Black</a>
# </h2>]
# [<h2 class="ProductItem__Title Heading">
# <a href="/products/california-chain">California Chain 7mm</a>
# ...

# %%
######### Usando STRING NO ME ENTREGA LOS NOMBRES3###########
for product in all_products:
    name_products = product.find(class_='ProductItem__Title Heading')
    print(name_products.string)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
######probando el string con precios#####
######### Usando STRING NO ME ENTREGA LOS NOMBRES3###########
for product in all_products:
    name_products = product.find(class_='ProductItem__Title Heading')
    print(name_products.a.string)

    

    price_products = product.find(class_='ProductItem__Price Price Text--subdued')
    print(price_products.string)

    ### Conlusión, no me entrega los nombres  porque estan puestos en la etiqueta "a href"
# Out:
# Retro Pilot
# $34.990
# Polygon Vintage
# $34.990
# Square Leopard Retro
# $34.990
# Square Black Retro
# $34.990
# Tortoise Black
# $34.990
# Tortoise Leopard
# $34.990
# Jack Black Leopard
# $34.990
# Jack Black
# $34.990
# California Chain 7mm
# $29.990
# Miami Chain 7mm
# $29.990
# Cuban Chain 3mm
# $26.990
# Angular Wing Chain
# $29.990
# Silver Chain
# $23.990
# Miami Chain 9mm
# $31.990
# Silver Cuban Link 5mm
# $19.990
# Silver Cuban Link 9mm
# $22.990
# Feather Earring
# $10.990
# Oval Vintage
# $34.990
# California Chain 7mm
# $29.990
# Oval Vintage
# $34.990
# California Chain 7mm
# $29.990
# Square Black Retro
# $34.990
# Silver Bracelet
# $22.990
# Silver bracelet 3mm
# $20.990
# Square Black Retro
# $34.990
# Silver Bracelet
# $22.990
# Silver bracelet 3mm
# $20.990
